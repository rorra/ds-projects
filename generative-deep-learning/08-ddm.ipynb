# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-colorblind")

import math

import tensorflow as tf
from tensorflow.keras import (
    layers,
    models,
    optimizers,
    utils,
    callbacks,
    metrics,
    losses,
    activations,
)

from utils import display, sample_batch
# Out:
# 2024-03-16 00:03:26.080935: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-16 00:03:26.080956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-16 00:03:26.081614: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# # 0. Parameters

# %%
IMAGE_SIZE = 64
BATCH_SIZE = 64
DATASET_REPETITIONS = 5
LOAD_MODEL = False

NOISE_EMBEDDING_SIZE = 32
PLOT_DIFFUSION_STEPS = 20

# optimization
EMA = 0.999
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-4
EPOCHS = 50

# %% [markdown]
# # 1. Prepare the Data

# %%
# !kaggle datasets download nunenuh/pytorch-challange-flower-dataset
# Out:
# Downloading pytorch-challange-flower-dataset.zip to /home/rorra/ds-projects/generative-deep-learning
# 100%|███████████████████████████████████████▊| 329M/330M [00:10<00:00, 35.1MB/s]
# 100%|████████████████████████████████████████| 330M/330M [00:10<00:00, 31.6MB/s]

# %%
# !unzip pytorch-challange-flower-dataset.zip -d data
# !rm pytorch-challange-flower-dataset.zip
# Out:
# Archive:  pytorch-challange-flower-dataset.zip
#   inflating: data/README.md
#   inflating: data/cat_to_name.json
#   inflating: data/dataset/test/image_00005.jpg
#   inflating: data/dataset/test/image_00006.jpg
#   inflating: data/dataset/test/image_00024.jpg
#   inflating: data/dataset/test/image_00025.jpg
#   inflating: data/dataset/test/image_00029.jpg
#   inflating: data/dataset/test/image_00050.jpg
#   inflating: data/dataset/test/image_00060.jpg
#   inflating: data/dataset/test/image_00065.jpg
#   inflating: data/dataset/test/image_00092.jpg
#   inflating: data/dataset/test/image_00099.jpg
#   inflating: data/dataset/test/image_00114.jpg
#   inflating: data/dataset/test/image_00116.jpg
#   inflating: data/dataset/test/image_00132.jpg
#   inflating: data/dataset/test/image_00176.jpg
#   inflating: data/dataset/test/image_00177.jpg
#   inflating: data/dataset/test/image_00187.jpg
#   inflating: data/dataset/test/image_00191.jpg
#   inflating: data/dataset/test/image_00202.jpg
#   inflating: data/dataset/test/image_00203.jpg
#   inflating: data/dataset/test/image_00204.jpg
#   inflating: data/dataset/test/image_00212.jpg
#   inflating: data/dataset/test/image_00222.jpg
#   inflating: data/dataset/test/image_00239.jpg
#   inflating: data/dataset/test/image_00248.jpg
#   inflating: data/dataset/test/image_00251.jpg
#   inflating: data/dataset/test/image_00258.jpg
#   inflating: data/dataset/test/image_00260.jpg
#   inflating: data/dataset/test/image_00277.jpg
#   inflating: data/dataset/test/image_00282.jpg
#   inflating: data/dataset/test/image_00284.jpg
#   inflating: data/dataset/test/image_00288.jpg
#   inflating: data/dataset/test/image_00291.jpg
#   inflating: data/dataset/test/image_00294.jpg
#   inflating: data/dataset/test/image_00303.jpg
#   inflating: data/dataset/test/image_00319.jpg
#   inflating: data/dataset/test/image_00320.jpg
#   inflating: data/dataset/test/image_00324.jpg
#   inflating: data/dataset/test/image_00330.jpg
#   inflating: data/dataset/test/image_00335.jpg
#   inflating: data/dataset/test/image_00337.jpg
#   inflating: data/dataset/test/image_00345.jpg
#   inflating: data/dataset/test/image_00349.jpg
#   inflating: data/dataset/test/image_00353.jpg
#   inflating: data/dataset/test/image_00365.jpg
#   inflating: data/dataset/test/image_00369.jpg
#   inflating: data/dataset/test/image_00387.jpg
#   inflating: data/dataset/test/image_00389.jpg
#   inflating: data/dataset/test/image_00394.jpg
#   inflating: data/dataset/test/image_00400.jpg
#   inflating: data/dataset/test/image_00401.jpg
#   inflating: data/dataset/test/image_00409.jpg
#   inflating: data/dataset/test/image_00426.jpg
#   inflating: data/dataset/test/image_00445.jpg
#   inflating: data/dataset/test/image_00457.jpg
#   inflating: data/dataset/test/image_00467.jpg
#   inflating: data/dataset/test/image_00474.jpg
#   inflating: data/dataset/test/image_00477.jpg
#   inflating: data/dataset/test/image_00482.jpg
#   inflating: data/dataset/test/image_00520.jpg
#   inflating: data/dataset/test/image_00526.jpg
#   inflating: data/dataset/test/image_00540.jpg
#   inflating: data/dataset/test/image_00551.jpg
#   inflating: data/dataset/test/image_00563.jpg
#   inflating: data/dataset/test/image_00582.jpg
#   inflating: data/dataset/test/image_00584.jpg
#   inflating: data/dataset/test/image_00594.jpg
#   inflating: data/dataset/test/image_00610.jpg
#   inflating: data/dataset/test/image_00617.jpg
#   inflating: data/dataset/test/image_00634.jpg
#   inflating: data/dataset/test/image_00645.jpg
#   inflating: data/dataset/test/image_00654.jpg
#   inflating: data/dataset/test/image_00676.jpg
#   inflating: data/dataset/test/image_00699.jpg
#   inflating: data/dataset/test/image_00708.jpg
#   inflating: data/dataset/test/image_00724.jpg
#   inflating: data/dataset/test/image_00726.jpg
#   inflating: data/dataset/test/image_00740.jpg
#   inflating: data/dataset/test/image_00745.jpg
#   inflating: data/dataset/test/image_00755.jpg
#   inflating: data/dataset/test/image_00756.jpg
#   inflating: data/dataset/test/image_00779.jpg
#   inflating: data/dataset/test/image_00798.jpg
#   inflating: data/dataset/test/image_00814.jpg
#   inflating: data/dataset/test/image_00815.jpg
#   inflating: data/dataset/test/image_00818.jpg
#   inflating: data/dataset/test/image_00825.jpg
#   inflating: data/dataset/test/image_00826.jpg
#   inflating: data/dataset/test/image_00828.jpg
#   inflating: data/dataset/test/image_00833.jpg
#   inflating: data/dataset/test/image_00869.jpg
#   inflating: data/dataset/test/image_00888.jpg
#   inflating: data/dataset/test/image_00898.jpg
#   inflating: data/dataset/test/image_00926.jpg
#   inflating: data/dataset/test/image_00946.jpg
#   inflating: data/dataset/test/image_00958.jpg
#   inflating: data/dataset/test/image_00961.jpg
#   inflating: data/dataset/test/image_00969.jpg
#   inflating: data/dataset/test/image_00970.jpg
#   inflating: data/dataset/test/image_00976.jpg
#   inflating: data/dataset/test/image_00990.jpg
#   inflating: data/dataset/test/image_00996.jpg
#   inflating: data/dataset/test/image_00999.jpg
#   inflating: data/dataset/test/image_01003.jpg
#   inflating: data/dataset/test/image_01026.jpg
#   inflating: data/dataset/test/image_01038.jpg
#   inflating: data/dataset/test/image_01061.jpg
#   inflating: data/dataset/test/image_01071.jpg
#   inflating: data/dataset/test/image_01077.jpg
#   inflating: data/dataset/test/image_01078.jpg
#   inflating: data/dataset/test/image_01090.jpg
#   inflating: data/dataset/test/image_01092.jpg
#   inflating: data/dataset/test/image_01109.jpg
#   inflating: data/dataset/test/image_01115.jpg
#   inflating: data/dataset/test/image_01119.jpg
#   inflating: data/dataset/test/image_01125.jpg
#   inflating: data/dataset/test/image_01151.jpg
#   inflating: data/dataset/test/image_01165.jpg
#   inflating: data/dataset/test/image_01173.jpg
#   inflating: data/dataset/test/image_01191.jpg
#   inflating: data/dataset/test/image_01200.jpg
#   inflating: data/dataset/test/image_01209.jpg
#   inflating: data/dataset/test/image_01213.jpg
#   inflating: data/dataset/test/image_01249.jpg
#   inflating: data/dataset/test/image_01254.jpg
#   inflating: data/dataset/test/image_01256.jpg
#   inflating: data/dataset/test/image_01276.jpg
#   inflating: data/dataset/test/image_01305.jpg
#   inflating: data/dataset/test/image_01307.jpg
#   inflating: data/dataset/test/image_01312.jpg
#   inflating: data/dataset/test/image_01314.jpg
#   inflating: data/dataset/test/image_01316.jpg
#   inflating: data/dataset/test/image_01328.jpg
#   inflating: data/dataset/test/image_01335.jpg
#   inflating: data/dataset/test/image_01340.jpg
#   inflating: data/dataset/test/image_01362.jpg
#   inflating: data/dataset/test/image_01370.jpg
#   inflating: data/dataset/test/image_01388.jpg
#   inflating: data/dataset/test/image_01406.jpg
#   inflating: data/dataset/test/image_01407.jpg
#   inflating: data/dataset/test/image_01457.jpg
#   inflating: data/dataset/test/image_01468.jpg
#   inflating: data/dataset/test/image_01474.jpg
#   inflating: data/dataset/test/image_01502.jpg
#   inflating: data/dataset/test/image_01512.jpg
#   inflating: data/dataset/test/image_01515.jpg
#   inflating: data/dataset/test/image_01516.jpg
#   inflating: data/dataset/test/image_01518.jpg
#   inflating: data/dataset/test/image_01527.jpg
#   inflating: data/dataset/test/image_01530.jpg
#   inflating: data/dataset/test/image_01548.jpg
#   inflating: data/dataset/test/image_01560.jpg
#   inflating: data/dataset/test/image_01564.jpg
#   inflating: data/dataset/test/image_01578.jpg
#   inflating: data/dataset/test/image_01594.jpg
#   inflating: data/dataset/test/image_01598.jpg
#   inflating: data/dataset/test/image_01599.jpg
#   inflating: data/dataset/test/image_01603.jpg
#   inflating: data/dataset/test/image_01609.jpg
#   inflating: data/dataset/test/image_01610.jpg
#   inflating: data/dataset/test/image_01614.jpg
#   inflating: data/dataset/test/image_01618.jpg
#   inflating: data/dataset/test/image_01650.jpg
#   inflating: data/dataset/test/image_01653.jpg
#   inflating: data/dataset/test/image_01661.jpg
#   inflating: data/dataset/test/image_01662.jpg
#   inflating: data/dataset/test/image_01666.jpg
#   inflating: data/dataset/test/image_01672.jpg
#   inflating: data/dataset/test/image_01679.jpg
#   inflating: data/dataset/test/image_01685.jpg
#   inflating: data/dataset/test/image_01686.jpg
#   inflating: data/dataset/test/image_01735.jpg
#   inflating: data/dataset/test/image_01737.jpg
#   inflating: data/dataset/test/image_01742.jpg
#   inflating: data/dataset/test/image_01748.jpg
#   inflating: data/dataset/test/image_01755.jpg
#   inflating: data/dataset/test/image_01759.jpg
#   inflating: data/dataset/test/image_01770.jpg
#   inflating: data/dataset/test/image_01774.jpg
#   inflating: data/dataset/test/image_01777.jpg
#   inflating: data/dataset/test/image_01789.jpg
#   inflating: data/dataset/test/image_01805.jpg
#   inflating: data/dataset/test/image_01809.jpg
#   inflating: data/dataset/test/image_01810.jpg
#   inflating: data/dataset/test/image_01818.jpg
#   inflating: data/dataset/test/image_01830.jpg
#   inflating: data/dataset/test/image_01843.jpg
#   inflating: data/dataset/test/image_01848.jpg
#   inflating: data/dataset/test/image_01855.jpg
#   inflating: data/dataset/test/image_01856.jpg
#   inflating: data/dataset/test/image_01874.jpg
#   inflating: data/dataset/test/image_01888.jpg
#   inflating: data/dataset/test/image_01893.jpg
#   inflating: data/dataset/test/image_01903.jpg
#   inflating: data/dataset/test/image_01919.jpg
#   inflating: data/dataset/test/image_01928.jpg
#   inflating: data/dataset/test/image_01931.jpg
#   inflating: data/dataset/test/image_01949.jpg
#   inflating: data/dataset/test/image_01953.jpg
#   inflating: data/dataset/test/image_01983.jpg
#   inflating: data/dataset/test/image_01990.jpg
#   inflating: data/dataset/test/image_01993.jpg
#   inflating: data/dataset/test/image_01996.jpg
#   inflating: data/dataset/test/image_02020.jpg
#   inflating: data/dataset/test/image_02023.jpg
#   inflating: data/dataset/test/image_02041.jpg
#   inflating: data/dataset/test/image_02049.jpg
#   inflating: data/dataset/test/image_02051.jpg
#   inflating: data/dataset/test/image_02055.jpg
#   inflating: data/dataset/test/image_02062.jpg
#   inflating: data/dataset/test/image_02075.jpg
#   inflating: data/dataset/test/image_02078.jpg
#   inflating: data/dataset/test/image_02085.jpg
#   inflating: data/dataset/test/image_02088.jpg
#   inflating: data/dataset/test/image_02111.jpg
#   inflating: data/dataset/test/image_02115.jpg
#   inflating: data/dataset/test/image_02119.jpg
#   inflating: data/dataset/test/image_02135.jpg
#   inflating: data/dataset/test/image_02144.jpg
#   inflating: data/dataset/test/image_02154.jpg
#   inflating: data/dataset/test/image_02157.jpg
#   inflating: data/dataset/test/image_02167.jpg
#   inflating: data/dataset/test/image_02188.jpg
#   inflating: data/dataset/test/image_02193.jpg
#   inflating: data/dataset/test/image_02200.jpg
#   inflating: data/dataset/test/image_02222.jpg
#   inflating: data/dataset/test/image_02237.jpg
#   inflating: data/dataset/test/image_02245.jpg
#   inflating: data/dataset/test/image_02251.jpg
#   inflating: data/dataset/test/image_02257.jpg
#   inflating: data/dataset/test/image_02261.jpg
#   inflating: data/dataset/test/image_02263.jpg
#   inflating: data/dataset/test/image_02266.jpg
#   inflating: data/dataset/test/image_02270.jpg
#   inflating: data/dataset/test/image_02302.jpg
#   inflating: data/dataset/test/image_02305.jpg
#   inflating: data/dataset/test/image_02306.jpg
#   inflating: data/dataset/test/image_02329.jpg
#   inflating: data/dataset/test/image_02335.jpg
#   inflating: data/dataset/test/image_02346.jpg
#   inflating: data/dataset/test/image_02349.jpg
#   inflating: data/dataset/test/image_02365.jpg
#   inflating: data/dataset/test/image_02369.jpg
#   inflating: data/dataset/test/image_02370.jpg
#   inflating: data/dataset/test/image_02371.jpg
#   inflating: data/dataset/test/image_02386.jpg
#   inflating: data/dataset/test/image_02394.jpg
#   inflating: data/dataset/test/image_02400.jpg
#   inflating: data/dataset/test/image_02412.jpg
#   inflating: data/dataset/test/image_02426.jpg
#   inflating: data/dataset/test/image_02431.jpg
#   inflating: data/dataset/test/image_02433.jpg
#   inflating: data/dataset/test/image_02435.jpg
#   inflating: data/dataset/test/image_02472.jpg
#   inflating: data/dataset/test/image_02479.jpg
#   inflating: data/dataset/test/image_02484.jpg
#   inflating: data/dataset/test/image_02550.jpg
#   inflating: data/dataset/test/image_02557.jpg
#   inflating: data/dataset/test/image_02563.jpg
#   inflating: data/dataset/test/image_02568.jpg
#   inflating: data/dataset/test/image_02572.jpg
#   inflating: data/dataset/test/image_02576.jpg
#   inflating: data/dataset/test/image_02581.jpg
#   inflating: data/dataset/test/image_02583.jpg
#   inflating: data/dataset/test/image_02586.jpg
#   inflating: data/dataset/test/image_02613.jpg
#   inflating: data/dataset/test/image_02615.jpg
#   inflating: data/dataset/test/image_02663.jpg
#   inflating: data/dataset/test/image_02672.jpg
#   inflating: data/dataset/test/image_02677.jpg
#   inflating: data/dataset/test/image_02681.jpg
#   inflating: data/dataset/test/image_02687.jpg
#   inflating: data/dataset/test/image_02694.jpg
#   inflating: data/dataset/test/image_02695.jpg
#   inflating: data/dataset/test/image_02719.jpg
#   inflating: data/dataset/test/image_02721.jpg
#   inflating: data/dataset/test/image_02722.jpg
#   inflating: data/dataset/test/image_02737.jpg
#   inflating: data/dataset/test/image_02738.jpg
#   inflating: data/dataset/test/image_02743.jpg
#   inflating: data/dataset/test/image_02752.jpg
#   inflating: data/dataset/test/image_02772.jpg
#   inflating: data/dataset/test/image_02779.jpg
#   inflating: data/dataset/test/image_02785.jpg
#   inflating: data/dataset/test/image_02808.jpg
#   inflating: data/dataset/test/image_02821.jpg
#   inflating: data/dataset/test/image_02825.jpg
#   inflating: data/dataset/test/image_02841.jpg
#   inflating: data/dataset/test/image_02844.jpg
#   inflating: data/dataset/test/image_02865.jpg
#   inflating: data/dataset/test/image_02873.jpg
#   inflating: data/dataset/test/image_02893.jpg
#   inflating: data/dataset/test/image_02910.jpg
#   inflating: data/dataset/test/image_02912.jpg
#   inflating: data/dataset/test/image_02932.jpg
#   inflating: data/dataset/test/image_02933.jpg
#   inflating: data/dataset/test/image_02958.jpg
#   inflating: data/dataset/test/image_02971.jpg
#   inflating: data/dataset/test/image_02977.jpg
#   inflating: data/dataset/test/image_02978.jpg
#   inflating: data/dataset/test/image_02987.jpg
#   inflating: data/dataset/test/image_03000.jpg
#   inflating: data/dataset/test/image_03008.jpg
#   inflating: data/dataset/test/image_03026.jpg
#   inflating: data/dataset/test/image_03032.jpg
#   inflating: data/dataset/test/image_03039.jpg
#   inflating: data/dataset/test/image_03041.jpg
#   inflating: data/dataset/test/image_03044.jpg
#   inflating: data/dataset/test/image_03048.jpg
#   inflating: data/dataset/test/image_03049.jpg
#   inflating: data/dataset/test/image_03052.jpg
#   inflating: data/dataset/test/image_03054.jpg
#   inflating: data/dataset/test/image_03056.jpg
#   inflating: data/dataset/test/image_03058.jpg
#   inflating: data/dataset/test/image_03075.jpg
#   inflating: data/dataset/test/image_03098.jpg
#   inflating: data/dataset/test/image_03115.jpg
#   inflating: data/dataset/test/image_03130.jpg
#   inflating: data/dataset/test/image_03141.jpg
#   inflating: data/dataset/test/image_03147.jpg
#   inflating: data/dataset/test/image_03151.jpg
#   inflating: data/dataset/test/image_03165.jpg
#   inflating: data/dataset/test/image_03176.jpg
#   inflating: data/dataset/test/image_03177.jpg
#   inflating: data/dataset/test/image_03188.jpg
#   inflating: data/dataset/test/image_03197.jpg
#   inflating: data/dataset/test/image_03211.jpg
#   inflating: data/dataset/test/image_03243.jpg
#   inflating: data/dataset/test/image_03252.jpg
#   inflating: data/dataset/test/image_03258.jpg
#   inflating: data/dataset/test/image_03269.jpg
#   inflating: data/dataset/test/image_03291.jpg
#   inflating: data/dataset/test/image_03295.jpg
#   inflating: data/dataset/test/image_03299.jpg
#   inflating: data/dataset/test/image_03314.jpg
#   inflating: data/dataset/test/image_03319.jpg
#   inflating: data/dataset/test/image_03320.jpg
#   inflating: data/dataset/test/image_03347.jpg
#   inflating: data/dataset/test/image_03357.jpg
#   inflating: data/dataset/test/image_03359.jpg
#   inflating: data/dataset/test/image_03364.jpg
#   inflating: data/dataset/test/image_03382.jpg
#   inflating: data/dataset/test/image_03390.jpg
#   inflating: data/dataset/test/image_03409.jpg
#   inflating: data/dataset/test/image_03414.jpg
#   inflating: data/dataset/test/image_03440.jpg
#   inflating: data/dataset/test/image_03442.jpg
#   inflating: data/dataset/test/image_03454.jpg
#   inflating: data/dataset/test/image_03466.jpg
#   inflating: data/dataset/test/image_03481.jpg
#   inflating: data/dataset/test/image_03482.jpg
#   inflating: data/dataset/test/image_03484.jpg
#   inflating: data/dataset/test/image_03488.jpg
#   inflating: data/dataset/test/image_03489.jpg
#   inflating: data/dataset/test/image_03506.jpg
#   inflating: data/dataset/test/image_03509.jpg
#   inflating: data/dataset/test/image_03510.jpg
#   inflating: data/dataset/test/image_03512.jpg
#   inflating: data/dataset/test/image_03528.jpg
#   inflating: data/dataset/test/image_03538.jpg
#   inflating: data/dataset/test/image_03541.jpg
#   inflating: data/dataset/test/image_03542.jpg
#   inflating: data/dataset/test/image_03547.jpg
#   inflating: data/dataset/test/image_03575.jpg
#   inflating: data/dataset/test/image_03593.jpg
#   inflating: data/dataset/test/image_03599.jpg
#   inflating: data/dataset/test/image_03603.jpg
#   inflating: data/dataset/test/image_03613.jpg
#   inflating: data/dataset/test/image_03624.jpg
#   inflating: data/dataset/test/image_03625.jpg
#   inflating: data/dataset/test/image_03628.jpg
#   inflating: data/dataset/test/image_03633.jpg
#   inflating: data/dataset/test/image_03635.jpg
#   inflating: data/dataset/test/image_03645.jpg
#   inflating: data/dataset/test/image_03649.jpg
#   inflating: data/dataset/test/image_03652.jpg
#   inflating: data/dataset/test/image_03653.jpg
#   inflating: data/dataset/test/image_03662.jpg
#   inflating: data/dataset/test/image_03669.jpg
#   inflating: data/dataset/test/image_03672.jpg
#   inflating: data/dataset/test/image_03677.jpg
#   inflating: data/dataset/test/image_03689.jpg
#   inflating: data/dataset/test/image_03712.jpg
#   inflating: data/dataset/test/image_03714.jpg
#   inflating: data/dataset/test/image_03717.jpg
#   inflating: data/dataset/test/image_03718.jpg
#   inflating: data/dataset/test/image_03724.jpg
#   inflating: data/dataset/test/image_03734.jpg
#   inflating: data/dataset/test/image_03741.jpg
#   inflating: data/dataset/test/image_03783.jpg
#   inflating: data/dataset/test/image_03789.jpg
#   inflating: data/dataset/test/image_03807.jpg
#   inflating: data/dataset/test/image_03811.jpg
#   inflating: data/dataset/test/image_03815.jpg
#   inflating: data/dataset/test/image_03821.jpg
#   inflating: data/dataset/test/image_03830.jpg
#   inflating: data/dataset/test/image_03846.jpg
#   inflating: data/dataset/test/image_03855.jpg
#   inflating: data/dataset/test/image_03861.jpg
#   inflating: data/dataset/test/image_03864.jpg
#   inflating: data/dataset/test/image_03872.jpg
#   inflating: data/dataset/test/image_03893.jpg
#   inflating: data/dataset/test/image_03906.jpg
#   inflating: data/dataset/test/image_03911.jpg
#   inflating: data/dataset/test/image_03926.jpg
#   inflating: data/dataset/test/image_03939.jpg
#   inflating: data/dataset/test/image_03954.jpg
#   inflating: data/dataset/test/image_03960.jpg
#   inflating: data/dataset/test/image_03968.jpg
#   inflating: data/dataset/test/image_03973.jpg
#   inflating: data/dataset/test/image_03980.jpg
#   inflating: data/dataset/test/image_03984.jpg
#   inflating: data/dataset/test/image_03985.jpg
#   inflating: data/dataset/test/image_03986.jpg
#   inflating: data/dataset/test/image_03989.jpg
#   inflating: data/dataset/test/image_03994.jpg
#   inflating: data/dataset/test/image_03996.jpg
#   inflating: data/dataset/test/image_04012.jpg
#   inflating: data/dataset/test/image_04014.jpg
#   inflating: data/dataset/test/image_04016.jpg
#   inflating: data/dataset/test/image_04023.jpg
#   inflating: data/dataset/test/image_04052.jpg
#   inflating: data/dataset/test/image_04059.jpg
#   inflating: data/dataset/test/image_04077.jpg
#   inflating: data/dataset/test/image_04083.jpg
#   inflating: data/dataset/test/image_04090.jpg
#   inflating: data/dataset/test/image_04095.jpg
#   inflating: data/dataset/test/image_04112.jpg
#   inflating: data/dataset/test/image_04124.jpg
#   inflating: data/dataset/test/image_04137.jpg
#   inflating: data/dataset/test/image_04142.jpg
#   inflating: data/dataset/test/image_04145.jpg
#   inflating: data/dataset/test/image_04146.jpg
#   inflating: data/dataset/test/image_04160.jpg
#   inflating: data/dataset/test/image_04167.jpg
#   inflating: data/dataset/test/image_04168.jpg
#   inflating: data/dataset/test/image_04169.jpg
#   inflating: data/dataset/test/image_04181.jpg
#   inflating: data/dataset/test/image_04200.jpg
#   inflating: data/dataset/test/image_04221.jpg
#   inflating: data/dataset/test/image_04240.jpg
#   inflating: data/dataset/test/image_04254.jpg
#   inflating: data/dataset/test/image_04256.jpg
#   inflating: data/dataset/test/image_04272.jpg
#   inflating: data/dataset/test/image_04277.jpg
#   inflating: data/dataset/test/image_04292.jpg
#   inflating: data/dataset/test/image_04322.jpg
#   inflating: data/dataset/test/image_04334.jpg
#   inflating: data/dataset/test/image_04344.jpg
#   inflating: data/dataset/test/image_04364.jpg
#   inflating: data/dataset/test/image_04373.jpg
#   inflating: data/dataset/test/image_04382.jpg
#   inflating: data/dataset/test/image_04392.jpg
#   inflating: data/dataset/test/image_04400.jpg
#   inflating: data/dataset/test/image_04405.jpg
#   inflating: data/dataset/test/image_04407.jpg
#   inflating: data/dataset/test/image_04417.jpg
#   inflating: data/dataset/test/image_04420.jpg
#   inflating: data/dataset/test/image_04426.jpg
#   inflating: data/dataset/test/image_04428.jpg
#   inflating: data/dataset/test/image_04430.jpg
#   inflating: data/dataset/test/image_04431.jpg
#   inflating: data/dataset/test/image_04432.jpg
#   inflating: data/dataset/test/image_04458.jpg
#   inflating: data/dataset/test/image_04459.jpg
#   inflating: data/dataset/test/image_04468.jpg
#   inflating: data/dataset/test/image_04469.jpg
#   inflating: data/dataset/test/image_04473.jpg
#   inflating: data/dataset/test/image_04482.jpg
#   inflating: data/dataset/test/image_04488.jpg
#   inflating: data/dataset/test/image_04512.jpg
#   inflating: data/dataset/test/image_04514.jpg
#   inflating: data/dataset/test/image_04515.jpg
#   inflating: data/dataset/test/image_04519.jpg
#   inflating: data/dataset/test/image_04524.jpg
#   inflating: data/dataset/test/image_04555.jpg
#   inflating: data/dataset/test/image_04557.jpg
#   inflating: data/dataset/test/image_04563.jpg
#   inflating: data/dataset/test/image_04568.jpg
#   inflating: data/dataset/test/image_04573.jpg
#   inflating: data/dataset/test/image_04582.jpg
#   inflating: data/dataset/test/image_04586.jpg
#   inflating: data/dataset/test/image_04587.jpg
#   inflating: data/dataset/test/image_04588.jpg
#   inflating: data/dataset/test/image_04609.jpg
#   inflating: data/dataset/test/image_04627.jpg
#   inflating: data/dataset/test/image_04663.jpg
#   inflating: data/dataset/test/image_04665.jpg
#   inflating: data/dataset/test/image_04667.jpg
#   inflating: data/dataset/test/image_04671.jpg
#   inflating: data/dataset/test/image_04701.jpg
#   inflating: data/dataset/test/image_04707.jpg
#   inflating: data/dataset/test/image_04731.jpg
#   inflating: data/dataset/test/image_04733.jpg
#   inflating: data/dataset/test/image_04740.jpg
#   inflating: data/dataset/test/image_04742.jpg
#   inflating: data/dataset/test/image_04747.jpg
#   inflating: data/dataset/test/image_04786.jpg
#   inflating: data/dataset/test/image_04797.jpg
#   inflating: data/dataset/test/image_04801.jpg
#   inflating: data/dataset/test/image_04805.jpg
#   inflating: data/dataset/test/image_04806.jpg
#   inflating: data/dataset/test/image_04808.jpg
#   inflating: data/dataset/test/image_04810.jpg
#   inflating: data/dataset/test/image_04814.jpg
#   inflating: data/dataset/test/image_04819.jpg
#   inflating: data/dataset/test/image_04825.jpg
#   inflating: data/dataset/test/image_04851.jpg
#   inflating: data/dataset/test/image_04856.jpg
#   inflating: data/dataset/test/image_04860.jpg
#   inflating: data/dataset/test/image_04870.jpg
#   inflating: data/dataset/test/image_04875.jpg
#   inflating: data/dataset/test/image_04883.jpg
#   inflating: data/dataset/test/image_04890.jpg
#   inflating: data/dataset/test/image_04910.jpg
#   inflating: data/dataset/test/image_04912.jpg
#   inflating: data/dataset/test/image_04938.jpg
#   inflating: data/dataset/test/image_04966.jpg
#   inflating: data/dataset/test/image_04993.jpg
#   inflating: data/dataset/test/image_05013.jpg
#   inflating: data/dataset/test/image_05020.jpg
#   inflating: data/dataset/test/image_05033.jpg
#   inflating: data/dataset/test/image_05038.jpg
#   inflating: data/dataset/test/image_05039.jpg
#   inflating: data/dataset/test/image_05052.jpg
#   inflating: data/dataset/test/image_05064.jpg
#   inflating: data/dataset/test/image_05067.jpg
#   inflating: data/dataset/test/image_05100.jpg
#   inflating: data/dataset/test/image_05107.jpg
#   inflating: data/dataset/test/image_05109.jpg
#   inflating: data/dataset/test/image_05125.jpg
#   inflating: data/dataset/test/image_05133.jpg
#   inflating: data/dataset/test/image_05159.jpg
#   inflating: data/dataset/test/image_05166.jpg
#   inflating: data/dataset/test/image_05169.jpg
#   inflating: data/dataset/test/image_05186.jpg
#   inflating: data/dataset/test/image_05214.jpg
#   inflating: data/dataset/test/image_05230.jpg
#   inflating: data/dataset/test/image_05242.jpg
#   inflating: data/dataset/test/image_05253.jpg
#   inflating: data/dataset/test/image_05270.jpg
#   inflating: data/dataset/test/image_05277.jpg
#   inflating: data/dataset/test/image_05308.jpg
#   inflating: data/dataset/test/image_05324.jpg
#   inflating: data/dataset/test/image_05330.jpg
#   inflating: data/dataset/test/image_05331.jpg
#   inflating: data/dataset/test/image_05360.jpg
#   inflating: data/dataset/test/image_05362.jpg
#   inflating: data/dataset/test/image_05366.jpg
#   inflating: data/dataset/test/image_05391.jpg
#   inflating: data/dataset/test/image_05402.jpg
#   inflating: data/dataset/test/image_05413.jpg
#   inflating: data/dataset/test/image_05430.jpg
#   inflating: data/dataset/test/image_05440.jpg
#   inflating: data/dataset/test/image_05462.jpg
#   inflating: data/dataset/test/image_05466.jpg
#   inflating: data/dataset/test/image_05469.jpg
#   inflating: data/dataset/test/image_05485.jpg
#   inflating: data/dataset/test/image_05488.jpg
#   inflating: data/dataset/test/image_05493.jpg
#   inflating: data/dataset/test/image_05537.jpg
#   inflating: data/dataset/test/image_05549.jpg
#   inflating: data/dataset/test/image_05562.jpg
#   inflating: data/dataset/test/image_05582.jpg
#   inflating: data/dataset/test/image_05591.jpg
#   inflating: data/dataset/test/image_05592.jpg
#   inflating: data/dataset/test/image_05595.jpg
#   inflating: data/dataset/test/image_05602.jpg
#   inflating: data/dataset/test/image_05610.jpg
#   inflating: data/dataset/test/image_05614.jpg
#   inflating: data/dataset/test/image_05636.jpg
#   inflating: data/dataset/test/image_05637.jpg
#   inflating: data/dataset/test/image_05640.jpg
#   inflating: data/dataset/test/image_05653.jpg
#   inflating: data/dataset/test/image_05658.jpg
#   inflating: data/dataset/test/image_05678.jpg
#   inflating: data/dataset/test/image_05696.jpg
#   inflating: data/dataset/test/image_05711.jpg
#   inflating: data/dataset/test/image_05730.jpg
#   inflating: data/dataset/test/image_05731.jpg
#   inflating: data/dataset/test/image_05745.jpg
#   inflating: data/dataset/test/image_05761.jpg
#   inflating: data/dataset/test/image_05767.jpg
#   inflating: data/dataset/test/image_05769.jpg
#   inflating: data/dataset/test/image_05775.jpg
#   inflating: data/dataset/test/image_05787.jpg
#   inflating: data/dataset/test/image_05796.jpg
#   inflating: data/dataset/test/image_05797.jpg
#   inflating: data/dataset/test/image_05799.jpg
#   inflating: data/dataset/test/image_05806.jpg
#   inflating: data/dataset/test/image_05812.jpg
#   inflating: data/dataset/test/image_05824.jpg
#   inflating: data/dataset/test/image_05825.jpg
#   inflating: data/dataset/test/image_05833.jpg
#   inflating: data/dataset/test/image_05875.jpg
#   inflating: data/dataset/test/image_05878.jpg
#   inflating: data/dataset/test/image_05882.jpg
#   inflating: data/dataset/test/image_05890.jpg
#   inflating: data/dataset/test/image_05903.jpg
#   inflating: data/dataset/test/image_05927.jpg
#   inflating: data/dataset/test/image_05956.jpg
#   inflating: data/dataset/test/image_05959.jpg
#   inflating: data/dataset/test/image_05971.jpg
#   inflating: data/dataset/test/image_05994.jpg
#   inflating: data/dataset/test/image_06014.jpg
#   inflating: data/dataset/test/image_06017.jpg
#   inflating: data/dataset/test/image_06021.jpg
#   inflating: data/dataset/test/image_06031.jpg
#   inflating: data/dataset/test/image_06033.jpg
#   inflating: data/dataset/test/image_06037.jpg
#   inflating: data/dataset/test/image_06052.jpg
#   inflating: data/dataset/test/image_06083.jpg
#   inflating: data/dataset/test/image_06091.jpg
#   inflating: data/dataset/test/image_06099.jpg
#   inflating: data/dataset/test/image_06104.jpg
#   inflating: data/dataset/test/image_06130.jpg
#   inflating: data/dataset/test/image_06134.jpg
#   inflating: data/dataset/test/image_06138.jpg
#   inflating: data/dataset/test/image_06155.jpg
#   inflating: data/dataset/test/image_06159.jpg
#   inflating: data/dataset/test/image_06170.jpg
#   inflating: data/dataset/test/image_06175.jpg
#   inflating: data/dataset/test/image_06186.jpg
#   inflating: data/dataset/test/image_06196.jpg
#   inflating: data/dataset/test/image_06197.jpg
#   inflating: data/dataset/test/image_06202.jpg
#   inflating: data/dataset/test/image_06213.jpg
#   inflating: data/dataset/test/image_06215.jpg
#   inflating: data/dataset/test/image_06248.jpg
#   inflating: data/dataset/test/image_06249.jpg
#   inflating: data/dataset/test/image_06251.jpg
#   inflating: data/dataset/test/image_06266.jpg
#   inflating: data/dataset/test/image_06271.jpg
#   inflating: data/dataset/test/image_06279.jpg
#   inflating: data/dataset/test/image_06284.jpg
#   inflating: data/dataset/test/image_06290.jpg
#   inflating: data/dataset/test/image_06297.jpg
#   inflating: data/dataset/test/image_06318.jpg
#   inflating: data/dataset/test/image_06319.jpg
#   inflating: data/dataset/test/image_06320.jpg
#   inflating: data/dataset/test/image_06321.jpg
#   inflating: data/dataset/test/image_06351.jpg
#   inflating: data/dataset/test/image_06360.jpg
#   inflating: data/dataset/test/image_06369.jpg
#   inflating: data/dataset/test/image_06374.jpg
#   inflating: data/dataset/test/image_06410.jpg
#   inflating: data/dataset/test/image_06413.jpg
#   inflating: data/dataset/test/image_06454.jpg
#   inflating: data/dataset/test/image_06456.jpg
#   inflating: data/dataset/test/image_06457.jpg
#   inflating: data/dataset/test/image_06460.jpg
#   inflating: data/dataset/test/image_06470.jpg
#   inflating: data/dataset/test/image_06478.jpg
#   inflating: data/dataset/test/image_06479.jpg
#   inflating: data/dataset/test/image_06486.jpg
#   inflating: data/dataset/test/image_06497.jpg
#   inflating: data/dataset/test/image_06498.jpg
#   inflating: data/dataset/test/image_06500.jpg
#   inflating: data/dataset/test/image_06514.jpg
#   inflating: data/dataset/test/image_06526.jpg
#   inflating: data/dataset/test/image_06541.jpg
#   inflating: data/dataset/test/image_06546.jpg
#   inflating: data/dataset/test/image_06547.jpg
#   inflating: data/dataset/test/image_06580.jpg
#   inflating: data/dataset/test/image_06582.jpg
#   inflating: data/dataset/test/image_06583.jpg
#   inflating: data/dataset/test/image_06593.jpg
#   inflating: data/dataset/test/image_06611.jpg
#   inflating: data/dataset/test/image_06634.jpg
#   inflating: data/dataset/test/image_06641.jpg
#   inflating: data/dataset/test/image_06657.jpg
#   inflating: data/dataset/test/image_06670.jpg
#   inflating: data/dataset/test/image_06673.jpg
#   inflating: data/dataset/test/image_06708.jpg
#   inflating: data/dataset/test/image_06720.jpg
#   inflating: data/dataset/test/image_06726.jpg
#   inflating: data/dataset/test/image_06743.jpg
#   inflating: data/dataset/test/image_06752.jpg
#   inflating: data/dataset/test/image_06754.jpg
#   inflating: data/dataset/test/image_06760.jpg
#   inflating: data/dataset/test/image_06764.jpg
#   inflating: data/dataset/test/image_06805.jpg
#   inflating: data/dataset/test/image_06807.jpg
#   inflating: data/dataset/test/image_06815.jpg
#   inflating: data/dataset/test/image_06849.jpg
#   inflating: data/dataset/test/image_06864.jpg
#   inflating: data/dataset/test/image_06871.jpg
#   inflating: data/dataset/test/image_06887.jpg
#   inflating: data/dataset/test/image_06903.jpg
#   inflating: data/dataset/test/image_06929.jpg
#   inflating: data/dataset/test/image_06933.jpg
#   inflating: data/dataset/test/image_06941.jpg
#   inflating: data/dataset/test/image_06954.jpg
#   inflating: data/dataset/test/image_06961.jpg
#   inflating: data/dataset/test/image_06984.jpg
#   inflating: data/dataset/test/image_06986.jpg
#   inflating: data/dataset/test/image_06992.jpg
#   inflating: data/dataset/test/image_07006.jpg
#   inflating: data/dataset/test/image_07010.jpg
#   inflating: data/dataset/test/image_07016.jpg
#   inflating: data/dataset/test/image_07018.jpg
#   inflating: data/dataset/test/image_07035.jpg
#   inflating: data/dataset/test/image_07043.jpg
#   inflating: data/dataset/test/image_07056.jpg
#   inflating: data/dataset/test/image_07079.jpg
#   inflating: data/dataset/test/image_07080.jpg
#   inflating: data/dataset/test/image_07082.jpg
#   inflating: data/dataset/test/image_07090.jpg
#   inflating: data/dataset/test/image_07104.jpg
#   inflating: data/dataset/test/image_07117.jpg
#   inflating: data/dataset/test/image_07139.jpg
#   inflating: data/dataset/test/image_07140.jpg
#   inflating: data/dataset/test/image_07142.jpg
#   inflating: data/dataset/test/image_07173.jpg
#   inflating: data/dataset/test/image_07181.jpg
#   inflating: data/dataset/test/image_07182.jpg
#   inflating: data/dataset/test/image_07185.jpg
#   inflating: data/dataset/test/image_07191.jpg
#   inflating: data/dataset/test/image_07198.jpg
#   inflating: data/dataset/test/image_07199.jpg
#   inflating: data/dataset/test/image_07211.jpg
#   inflating: data/dataset/test/image_07215.jpg
#   inflating: data/dataset/test/image_07218.jpg
#   inflating: data/dataset/test/image_07219.jpg
#   inflating: data/dataset/test/image_07234.jpg
#   inflating: data/dataset/test/image_07241.jpg
#   inflating: data/dataset/test/image_07242.jpg
#   inflating: data/dataset/test/image_07250.jpg
#   inflating: data/dataset/test/image_07266.jpg
#   inflating: data/dataset/test/image_07267.jpg
#   inflating: data/dataset/test/image_07269.jpg
#   inflating: data/dataset/test/image_07276.jpg
#   inflating: data/dataset/test/image_07308.jpg
#   inflating: data/dataset/test/image_07327.jpg
#   inflating: data/dataset/test/image_07333.jpg
#   inflating: data/dataset/test/image_07346.jpg
#   inflating: data/dataset/test/image_07352.jpg
#   inflating: data/dataset/test/image_07357.jpg
#   inflating: data/dataset/test/image_07358.jpg
#   inflating: data/dataset/test/image_07361.jpg
#   inflating: data/dataset/test/image_07370.jpg
#   inflating: data/dataset/test/image_07388.jpg
#   inflating: data/dataset/test/image_07395.jpg
#   inflating: data/dataset/test/image_07399.jpg
#   inflating: data/dataset/test/image_07400.jpg
#   inflating: data/dataset/test/image_07415.jpg
#   inflating: data/dataset/test/image_07434.jpg
#   inflating: data/dataset/test/image_07436.jpg
#   inflating: data/dataset/test/image_07468.jpg
#   inflating: data/dataset/test/image_07470.jpg
#   inflating: data/dataset/test/image_07472.jpg
#   inflating: data/dataset/test/image_07487.jpg
#   inflating: data/dataset/test/image_07505.jpg
#   inflating: data/dataset/test/image_07508.jpg
#   inflating: data/dataset/test/image_07514.jpg
#   inflating: data/dataset/test/image_07519.jpg
#   inflating: data/dataset/test/image_07536.jpg
#   inflating: data/dataset/test/image_07550.jpg
#   inflating: data/dataset/test/image_07551.jpg
#   inflating: data/dataset/test/image_07561.jpg
#   inflating: data/dataset/test/image_07573.jpg
#   inflating: data/dataset/test/image_07584.jpg
#   inflating: data/dataset/test/image_07596.jpg
#   inflating: data/dataset/test/image_07597.jpg
#   inflating: data/dataset/test/image_07606.jpg
#   inflating: data/dataset/test/image_07622.jpg
#   inflating: data/dataset/test/image_07646.jpg
#   inflating: data/dataset/test/image_07668.jpg
#   inflating: data/dataset/test/image_07672.jpg
#   inflating: data/dataset/test/image_07676.jpg
#   inflating: data/dataset/test/image_07683.jpg
#   inflating: data/dataset/test/image_07696.jpg
#   inflating: data/dataset/test/image_07708.jpg
#   inflating: data/dataset/test/image_07709.jpg
#   inflating: data/dataset/test/image_07719.jpg
#   inflating: data/dataset/test/image_07737.jpg
#   inflating: data/dataset/test/image_07753.jpg
#   inflating: data/dataset/test/image_07758.jpg
#   inflating: data/dataset/test/image_07777.jpg
#   inflating: data/dataset/test/image_07787.jpg
#   inflating: data/dataset/test/image_07833.jpg
#   inflating: data/dataset/test/image_07838.jpg
#   inflating: data/dataset/test/image_07840.jpg
#   inflating: data/dataset/test/image_07854.jpg
#   inflating: data/dataset/test/image_07857.jpg
#   inflating: data/dataset/test/image_07871.jpg
#   inflating: data/dataset/test/image_07874.jpg
#   inflating: data/dataset/test/image_07896.jpg
#   inflating: data/dataset/test/image_07897.jpg
#   inflating: data/dataset/test/image_07899.jpg
#   inflating: data/dataset/test/image_07902.jpg
#   inflating: data/dataset/test/image_07926.jpg
#   inflating: data/dataset/test/image_07936.jpg
#   inflating: data/dataset/test/image_07938.jpg
#   inflating: data/dataset/test/image_07939.jpg
#   inflating: data/dataset/test/image_07949.jpg
#   inflating: data/dataset/test/image_07952.jpg
#   inflating: data/dataset/test/image_07983.jpg
#   inflating: data/dataset/test/image_07988.jpg
#   inflating: data/dataset/test/image_08004.jpg
#   inflating: data/dataset/test/image_08012.jpg
#   inflating: data/dataset/test/image_08015.jpg
#   inflating: data/dataset/test/image_08023.jpg
#   inflating: data/dataset/test/image_08030.jpg
#   inflating: data/dataset/test/image_08042.jpg
#   inflating: data/dataset/test/image_08061.jpg
#   inflating: data/dataset/test/image_08070.jpg
#   inflating: data/dataset/test/image_08084.jpg
#   inflating: data/dataset/test/image_08088.jpg
#   inflating: data/dataset/test/image_08099.jpg
#   inflating: data/dataset/test/image_08104.jpg
#   inflating: data/dataset/test/image_08106.jpg
#   inflating: data/dataset/test/image_08108.jpg
#   inflating: data/dataset/test/image_08127.jpg
#   inflating: data/dataset/test/image_08129.jpg
#   inflating: data/dataset/test/image_08133.jpg
#   inflating: data/dataset/test/image_08134.jpg
#   inflating: data/dataset/test/image_08144.jpg
#   inflating: data/dataset/test/image_08172.jpg
#   inflating: data/dataset/test/image_08177.jpg
#   inflating: data/dataset/train/1/image_06734.jpg
#   inflating: data/dataset/train/1/image_06735.jpg
#   inflating: data/dataset/train/1/image_06736.jpg
#   inflating: data/dataset/train/1/image_06737.jpg
#   inflating: data/dataset/train/1/image_06738.jpg
#   inflating: data/dataset/train/1/image_06740.jpg
#   inflating: data/dataset/train/1/image_06741.jpg
#   inflating: data/dataset/train/1/image_06742.jpg
#   inflating: data/dataset/train/1/image_06744.jpg
#   inflating: data/dataset/train/1/image_06745.jpg
#   inflating: data/dataset/train/1/image_06746.jpg
#   inflating: data/dataset/valid/76/image_02504.jpg
#   inflating: data/dataset/valid/76/image_02512.jpg
#   inflating: data/dataset/valid/76/image_02513.jpg
#   inflating: data/dataset/valid/76/image_02514.jpg
#   inflating: data/dataset/valid/76/image_02523.jpg
#   inflating: data/dataset/valid/76/image_02525.jpg
#   inflating: data/dataset/valid/76/image_02529.jpg
#   inflating: data/dataset/valid/76/image_02530.jpg
#   inflating: data/dataset/valid/76/image_02537.jpg
#   inflating: data/dataset/valid/77/image_00028.jpg
#   inflating: data/dataset/valid/77/image_00059.jpg
#   inflating: data/dataset/valid/77/image_00061.jpg
#   inflating: data/dataset/valid/77/image_00063.jpg
#   inflating: data/dataset/valid/77/image_00071.jpg
#   inflating: data/dataset/valid/77/image_00072.jpg
#   inflating: data/dataset/valid/77/image_00078.jpg
#   inflating: data/dataset/valid/77/image_00081.jpg
#   inflating: data/dataset/valid/77/image_00104.jpg
#   inflating: data/dataset/valid/77/image_00112.jpg
#   inflating: data/dataset/valid/77/image_00137.jpg
#   inflating: data/dataset/valid/77/image_00143.jpg
#   inflating: data/dataset/valid/77/image_00160.jpg
#   inflating: data/dataset/valid/77/image_00174.jpg
#   inflating: data/dataset/valid/77/image_00178.jpg
#   inflating: data/dataset/valid/77/image_00188.jpg
#   inflating: data/dataset/valid/77/image_00200.jpg
#   inflating: data/dataset/valid/77/image_00218.jpg
#   inflating: data/dataset/valid/77/image_00231.jpg
#   inflating: data/dataset/valid/77/image_00245.jpg
#   inflating: data/dataset/valid/77/image_00246.jpg
#   inflating: data/dataset/valid/78/image_01844.jpg
#   inflating: data/dataset/valid/78/image_01862.jpg
#   inflating: data/dataset/valid/78/image_01894.jpg
#   inflating: data/dataset/valid/78/image_01910.jpg
#   inflating: data/dataset/valid/78/image_01914.jpg
#   inflating: data/dataset/valid/78/image_01922.jpg
#   inflating: data/dataset/valid/78/image_01929.jpg
#   inflating: data/dataset/valid/78/image_01937.jpg
#   inflating: data/dataset/valid/78/image_01938.jpg
#   inflating: data/dataset/valid/78/image_01944.jpg
#   inflating: data/dataset/valid/78/image_01962.jpg
#   inflating: data/dataset/valid/79/image_06695.jpg
#   inflating: data/dataset/valid/79/image_06707.jpg
#   inflating: data/dataset/valid/79/image_06718.jpg
#   inflating: data/dataset/valid/79/image_06728.jpg
#   inflating: data/dataset/valid/8/image_03313.jpg
#   inflating: data/dataset/valid/8/image_03330.jpg
#   inflating: data/dataset/valid/8/image_03342.jpg
#   inflating: data/dataset/valid/8/image_03349.jpg
#   inflating: data/dataset/valid/8/image_03366.jpg
#   inflating: data/dataset/valid/80/image_01972.jpg
#   inflating: data/dataset/valid/80/image_01975.jpg
#   inflating: data/dataset/valid/80/image_01979.jpg
#   inflating: data/dataset/valid/80/image_01989.jpg
#   inflating: data/dataset/valid/80/image_01991.jpg
#   inflating: data/dataset/valid/80/image_01992.jpg
#   inflating: data/dataset/valid/80/image_02005.jpg
#   inflating: data/dataset/valid/80/image_02011.jpg
#   inflating: data/dataset/valid/97/image_07699.jpg
#   inflating: data/dataset/valid/97/image_07718.jpg
#   inflating: data/dataset/valid/97/image_07723.jpg
#   inflating: data/dataset/valid/97/image_07727.jpg
#   inflating: data/dataset/valid/97/image_07739.jpg
#   inflating: data/dataset/valid/97/image_07745.jpg
#   inflating: data/dataset/valid/98/image_07757.jpg
#   inflating: data/dataset/valid/98/image_07764.jpg
#   inflating: data/dataset/valid/98/image_07766.jpg
#   inflating: data/dataset/valid/98/image_07769.jpg
#   inflating: data/dataset/valid/98/image_07778.jpg
#   inflating: data/dataset/valid/98/image_07792.jpg
#   inflating: data/dataset/valid/98/image_07796.jpg
#   inflating: data/dataset/valid/98/image_07810.jpg
#   inflating: data/dataset/valid/98/image_07820.jpg
#   inflating: data/dataset/valid/98/image_07827.jpg
#   inflating: data/dataset/valid/99/image_07860.jpg
#   inflating: data/dataset/valid/99/image_07862.jpg
#   inflating: data/dataset/valid/99/image_07869.jpg
#   inflating: data/dataset/valid/99/image_07873.jpg
#   inflating: data/dataset/valid/99/image_07875.jpg
#   inflating: data/dataset/valid/99/image_08063.jpg
#   inflating: data/sample_submission.csv

# %%
train_data = utils.image_dataset_from_directory(
    "./data/dataset",
    labels=None,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=None,
    shuffle=True,
    seed=42,
    interpolation="bilinear",
)
# Out:
# Found 8189 files belonging to 1 classes.
# 2024-03-16 00:03:42.729347: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.735495: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.736868: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.738963: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.740254: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.741525: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.874061: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.875540: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.876931: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-03-16 00:03:42.878140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6956 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:0a:00.0, compute capability: 8.6
# 2024-03-16 00:03:43.042998: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory

# %%
# Preprocess the data
def preprocess(img):
    img = tf.cast(img, "float32") / 255.0
    return img


train = train_data.map(lambda x: preprocess(x))
train = train.repeat(DATASET_REPETITIONS)
train = train.batch(BATCH_SIZE, drop_remainder=True)

# %%
# Show some items of clothing from the training set
train_sample = sample_batch(train)
display(train_sample)

# %% [markdown]
# # 1.1 Diffusion schedules

# %%
def linear_diffusion_schedule(diffusion_times):
    min_rate = 0.0001
    max_rate = 0.02
    betas = min_rate + diffusion_times * (max_rate - min_rate)
    alphas = 1 - betas
    alpha_bars = tf.math.cumprod(alphas)
    signal_rates = tf.sqrt(alpha_bars)
    noise_rates = tf.sqrt(1 - alpha_bars)
    return noise_rates, signal_rates

# %%
def cosine_diffusion_schedule(diffusion_times):
    signal_rates = tf.cos(diffusion_times * math.pi / 2)
    noise_rates = tf.sin(diffusion_times * math.pi / 2)
    return noise_rates, signal_rates

# %%
def offset_cosine_diffusion_schedule(diffusion_times):
    min_signal_rate = 0.02
    max_signal_rate = 0.95
    start_angle = tf.acos(max_signal_rate)
    end_angle = tf.acos(min_signal_rate)

    diffusion_angles = start_angle + diffusion_times * (end_angle - start_angle)

    signal_rates = tf.cos(diffusion_angles)
    noise_rates = tf.sin(diffusion_angles)

    return noise_rates, signal_rates

# %%
T = 1000
diffusion_times = tf.convert_to_tensor([x / T for x in range(T)])
linear_noise_rates, linear_signal_rates = linear_diffusion_schedule(
    diffusion_times
)
cosine_noise_rates, cosine_signal_rates = cosine_diffusion_schedule(
    diffusion_times
)
(
    offset_cosine_noise_rates,
    offset_cosine_signal_rates,
) = offset_cosine_diffusion_schedule(diffusion_times)

# %%
plt.plot(
    diffusion_times, linear_signal_rates**2, linewidth=1.5, label="linear"
)
plt.plot(
    diffusion_times, cosine_signal_rates**2, linewidth=1.5, label="cosine"
)
plt.plot(
    diffusion_times,
    offset_cosine_signal_rates**2,
    linewidth=1.5,
    label="offset_cosine",
)

plt.xlabel("t/T", fontsize=12)
plt.ylabel(r"$\bar{\alpha_t}$ (signal)", fontsize=12)
plt.legend()
plt.show()

# %%
plt.plot(
    diffusion_times, linear_noise_rates**2, linewidth=1.5, label="linear"
)
plt.plot(
    diffusion_times, cosine_noise_rates**2, linewidth=1.5, label="cosine"
)
plt.plot(
    diffusion_times,
    offset_cosine_noise_rates**2,
    linewidth=1.5,
    label="offset_cosine",
)

plt.xlabel("t/T", fontsize=12)
plt.ylabel(r"$1-\bar{\alpha_t}$ (noise)", fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# # 2. Build the model

# %%
def sinusoidal_embedding(x):
    frequencies = tf.exp(
        tf.linspace(
            tf.math.log(1.0),
            tf.math.log(1000.0),
            NOISE_EMBEDDING_SIZE // 2,
        )
    )
    angular_speeds = 2.0 * math.pi * frequencies
    embeddings = tf.concat(
        [tf.sin(angular_speeds * x), tf.cos(angular_speeds * x)], axis=3
    )
    return embeddings

# %%
embedding_list = []
for y in np.arange(0, 1, 0.01):
    embedding_list.append(sinusoidal_embedding(np.array([[[[y]]]]))[0][0][0])
embedding_array = np.array(np.transpose(embedding_list))
fig, ax = plt.subplots()
ax.set_xticks(
    np.arange(0, 100, 10), labels=np.round(np.arange(0.0, 1.0, 0.1), 1)
)
ax.set_ylabel("embedding dimension", fontsize=8)
ax.set_xlabel("noise variance", fontsize=8)
plt.pcolor(embedding_array, cmap="coolwarm")
plt.colorbar(orientation="horizontal", label="embedding value")
ax.imshow(embedding_array, interpolation="nearest", origin="lower")
plt.show()

# %%
def ResidualBlock(width):
    def apply(x):
        input_width = x.shape[3]
        if input_width == width:
            residual = x
        else:
            residual = layers.Conv2D(width, kernel_size=1)(x)
        x = layers.BatchNormalization(center=False, scale=False)(x)
        x = layers.Conv2D(
            width, kernel_size=3, padding="same", activation=activations.swish
        )(x)
        x = layers.Conv2D(width, kernel_size=3, padding="same")(x)
        x = layers.Add()([x, residual])
        return x

    return apply


def DownBlock(width, block_depth):
    def apply(x):
        x, skips = x
        for _ in range(block_depth):
            x = ResidualBlock(width)(x)
            skips.append(x)
        x = layers.AveragePooling2D(pool_size=2)(x)
        return x

    return apply


def UpBlock(width, block_depth):
    def apply(x):
        x, skips = x
        x = layers.UpSampling2D(size=2, interpolation="bilinear")(x)
        for _ in range(block_depth):
            x = layers.Concatenate()([x, skips.pop()])
            x = ResidualBlock(width)(x)
        return x

    return apply

# %%
# Build the U-Net

noisy_images = layers.Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
x = layers.Conv2D(32, kernel_size=1)(noisy_images)

noise_variances = layers.Input(shape=(1, 1, 1))
noise_embedding = layers.Lambda(sinusoidal_embedding)(noise_variances)
noise_embedding = layers.UpSampling2D(size=IMAGE_SIZE, interpolation="nearest")(
    noise_embedding
)

x = layers.Concatenate()([x, noise_embedding])

skips = []

x = DownBlock(32, block_depth=2)([x, skips])
x = DownBlock(64, block_depth=2)([x, skips])
x = DownBlock(96, block_depth=2)([x, skips])

x = ResidualBlock(128)(x)
x = ResidualBlock(128)(x)

x = UpBlock(96, block_depth=2)([x, skips])
x = UpBlock(64, block_depth=2)([x, skips])
x = UpBlock(32, block_depth=2)([x, skips])

x = layers.Conv2D(3, kernel_size=1, kernel_initializer="zeros")(x)

unet = models.Model([noisy_images, noise_variances], x, name="unet")

# %%
class DiffusionModel(models.Model):
    def __init__(self):
        super().__init__()

        self.normalizer = layers.Normalization()
        self.network = unet
        self.ema_network = models.clone_model(self.network)
        self.diffusion_schedule = offset_cosine_diffusion_schedule

    def compile(self, **kwargs):
        super().compile(**kwargs)
        self.noise_loss_tracker = metrics.Mean(name="n_loss")

    @property
    def metrics(self):
        return [self.noise_loss_tracker]

    def denormalize(self, images):
        images = self.normalizer.mean + images * self.normalizer.variance**0.5
        return tf.clip_by_value(images, 0.0, 1.0)

    def denoise(self, noisy_images, noise_rates, signal_rates, training):
        if training:
            network = self.network
        else:
            network = self.ema_network
        pred_noises = network(
            [noisy_images, noise_rates**2], training=training
        )
        pred_images = (noisy_images - noise_rates * pred_noises) / signal_rates

        return pred_noises, pred_images

    def reverse_diffusion(self, initial_noise, diffusion_steps):
        num_images = initial_noise.shape[0]
        step_size = 1.0 / diffusion_steps
        current_images = initial_noise
        for step in range(diffusion_steps):
            diffusion_times = tf.ones((num_images, 1, 1, 1)) - step * step_size
            noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
            pred_noises, pred_images = self.denoise(
                current_images, noise_rates, signal_rates, training=False
            )
            next_diffusion_times = diffusion_times - step_size
            next_noise_rates, next_signal_rates = self.diffusion_schedule(
                next_diffusion_times
            )
            current_images = (
                next_signal_rates * pred_images + next_noise_rates * pred_noises
            )
        return pred_images

    def generate(self, num_images, diffusion_steps, initial_noise=None):
        if initial_noise is None:
            initial_noise = tf.random.normal(
                shape=(num_images, IMAGE_SIZE, IMAGE_SIZE, 3)
            )
        generated_images = self.reverse_diffusion(
            initial_noise, diffusion_steps
        )
        generated_images = self.denormalize(generated_images)
        return generated_images

    def train_step(self, images):
        images = self.normalizer(images, training=True)
        noises = tf.random.normal(shape=(BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3))

        diffusion_times = tf.random.uniform(
            shape=(BATCH_SIZE, 1, 1, 1), minval=0.0, maxval=1.0
        )
        noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)

        noisy_images = signal_rates * images + noise_rates * noises

        with tf.GradientTape() as tape:
            # train the network to separate noisy images to their components
            pred_noises, pred_images = self.denoise(
                noisy_images, noise_rates, signal_rates, training=True
            )

            noise_loss = self.loss(noises, pred_noises)  # used for training

        gradients = tape.gradient(noise_loss, self.network.trainable_weights)
        self.optimizer.apply_gradients(
            zip(gradients, self.network.trainable_weights)
        )

        self.noise_loss_tracker.update_state(noise_loss)

        for weight, ema_weight in zip(
            self.network.weights, self.ema_network.weights
        ):
            ema_weight.assign(EMA * ema_weight + (1 - EMA) * weight)

        return {m.name: m.result() for m in self.metrics}

    def test_step(self, images):
        images = self.normalizer(images, training=False)
        noises = tf.random.normal(shape=(BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, 3))
        diffusion_times = tf.random.uniform(
            shape=(BATCH_SIZE, 1, 1, 1), minval=0.0, maxval=1.0
        )
        noise_rates, signal_rates = self.diffusion_schedule(diffusion_times)
        noisy_images = signal_rates * images + noise_rates * noises
        pred_noises, pred_images = self.denoise(
            noisy_images, noise_rates, signal_rates, training=False
        )
        noise_loss = self.loss(noises, pred_noises)
        self.noise_loss_tracker.update_state(noise_loss)

        return {m.name: m.result() for m in self.metrics}

# %%
ddm = DiffusionModel()
ddm.normalizer.adapt(train)

# %%
if LOAD_MODEL:
    ddm.built = True
    ddm.load_weights("./checkpoint/checkpoint.ckpt")

# %% [markdown]
# # 3.Train the model

# %%
ddm.compile(
    optimizer=optimizers.experimental.AdamW(
        learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY
    ),
    loss=losses.mean_absolute_error,
)

# %%
# run training and plot generated images periodically
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.ckpt",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")


class ImageGenerator(callbacks.Callback):
    def __init__(self, num_img):
        self.num_img = num_img

    def on_epoch_end(self, epoch, logs=None):
        generated_images = self.model.generate(
            num_images=self.num_img,
            diffusion_steps=PLOT_DIFFUSION_STEPS,
        ).numpy()
        display(
            generated_images,
            save_to="./output/generated_img_%03d.png" % (epoch),
        )


image_generator_callback = ImageGenerator(num_img=10)

ddm.fit(
    train,
    epochs=EPOCHS,
    callbacks=[
        model_checkpoint_callback,
        tensorboard_callback,
        image_generator_callback,
    ],
)

# %% [markdown]
# # 4. Inference

# %%
# Generate some novel images of flowers
generated_images = ddm.generate(num_images=10, diffusion_steps=20).numpy()
display(generated_images)

# %%
# View improvement over greater number of diffusion steps
for diffusion_steps in list(np.arange(1, 6, 1)) + [20] + [100]:
    tf.random.set_seed(42)
    generated_images = ddm.generate(
        num_images=10,
        diffusion_steps=diffusion_steps,
    ).numpy()
    display(generated_images)

# %%
# Interpolation between two points in the latent space
tf.random.set_seed(100)


def spherical_interpolation(a, b, t):
    return np.sin(t * math.pi / 2) * a + np.cos(t * math.pi / 2) * b


for i in range(5):
    a = tf.random.normal(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    b = tf.random.normal(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
    initial_noise = np.array(
        [spherical_interpolation(a, b, t) for t in np.arange(0, 1.1, 0.1)]
    )
    generated_images = ddm.generate(
        num_images=2, diffusion_steps=20, initial_noise=initial_noise
    ).numpy()
    display(generated_images, n=11)

# %%
# Generate some novel images of flowers
generated_images = ddm.generate(num_images=10, diffusion_steps=100).numpy()
display(generated_images)
